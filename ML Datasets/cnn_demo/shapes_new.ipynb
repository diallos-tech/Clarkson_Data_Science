# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
batch_size = 32
epochs = 200
IMG_HEIGHT = 30
IMG_WIDTH = 30
TRAIN_PATH = 'shapes'
VAL_PATH = 'val_shapes'

# %%
train_data =  tf.keras.utils.image_dataset_from_directory(
    batch_size=batch_size,
    label_mode='int',
    directory=TRAIN_PATH,
    color_mode="grayscale",
    shuffle=True,
    image_size=(IMG_HEIGHT, IMG_WIDTH))
# Out:
# Found 40 files belonging to 2 classes.

# %%
val_data =  tf.keras.utils.image_dataset_from_directory(
    batch_size=batch_size,
    label_mode='int',
    directory=VAL_PATH,
    shuffle=True,
    color_mode="grayscale",
    image_size=(IMG_HEIGHT, IMG_WIDTH))
# Out:
# Found 10 files belonging to 2 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['0', '1']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    #print(images[i].numpy().max())
    plt.imshow(images[i].numpy(),cmap='gray' )
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
train_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 30, 30, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
#Build the model
from tensorflow.keras import layers
model = Sequential([
    layers.Input(shape=(IMG_HEIGHT,IMG_WIDTH,1)),
    layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(len(class_names), activation="softmax"),
])
# Compile the model
model.compile(optimizer='adam',              
              loss="sparse_categorical_crossentropy",              
              metrics=['accuracy'])
# print the model architecture
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)              │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │         4,610 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,426 (91.51 KB)
#  Trainable params: 23,426 (91.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_data,
    epochs=epochs,
    validation_data=val_data
)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4833 - loss: 37.3462 - val_accuracy: 0.5000 - val_loss: 40.5706
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3479 - loss: 51.0598 - val_accuracy: 0.5000 - val_loss: 7.2119
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6083 - loss: 23.0118 - val_accuracy: 0.5000 - val_loss: 6.2978
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6458 - loss: 15.0879 - val_accuracy: 0.5000 - val_loss: 11.3781
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5542 - loss: 21.0839 - val_accuracy: 0.7000 - val_loss: 5.3654
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6146 - loss: 14.1594 - val_accuracy: 0.6000 - val_loss: 6.1906
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5542 - loss: 10.8336 - val_accuracy: 0.5000 - val_loss: 8.7022
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6583 - loss: 7.5419 - val_accuracy: 0.5000 - val_loss: 7.4869
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7333 - loss: 4.6895 - val_accuracy: 0.7000 - val_loss: 4.2461
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5813 - loss: 10.7558 - val_accuracy: 0.6000 - val_loss: 5.0055
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6750 - loss: 8.8895 - val_accuracy: 0.7000 - val_loss: 4.0362
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7771 - loss: 3.3062 - val_accuracy: 0.6000 - val_loss: 6.2428
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 1.6517 - val_accuracy: 0.6000 - val_loss: 6.5585
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7833 - loss: 3.2618 - val_accuracy: 0.6000 - val_loss: 4.2914
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7604 - loss: 2.8187 - val_accuracy: 0.4000 - val_loss: 3.8240
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8104 - loss: 1.3244 - val_accuracy: 0.4000 - val_loss: 4.1980
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8417 - loss: 1.4212 - val_accuracy: 0.5000 - val_loss: 4.5724
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8583 - loss: 1.4050 - val_accuracy: 0.4000 - val_loss: 4.8660
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8958 - loss: 0
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9458 - loss: 0.6383 - val_accuracy: 0.5000 - val_loss: 4.2895
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.6000 - val_loss: 4.2846
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.9202e-05 - val_accuracy: 0.5000 - val_loss: 4.3472
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0299 - val_accuracy: 0.6000 - val_loss: 4.5893
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9125 - loss: 0.1473 - val_accuracy: 0.5000 - val_loss: 4.1255
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.4000 - val_loss: 3.6051
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.4000 - val_loss: 3.4202
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.3000 - val_loss: 3.4093
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.3000 - val_loss: 3.2677
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.0328 - val_accuracy: 0.4000 - val_loss: 3.1129
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 0.0882 - val_accuracy: 0.5000 - val_loss: 3.1465
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.5000 - val_loss: 3.3241
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.6000 - val_loss: 3.4747
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 0.2269 - val_accuracy: 0.6000 - val_loss: 3.4461
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9729 - loss: 0.0235 - val_accuracy: 0.6000 - val_loss: 3.3650
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.6000 - val_loss: 3.2216
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0440 - val_accuracy: 0.5000 - val_loss: 3.0877
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.3177e-04 - val_accuracy: 0.5000 - val_loss: 2.9897
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.5000 - val_loss: 2.9337
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0755 - val_accuracy: 0.4000 - val_loss: 2.9461
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.1173 - val_accuracy: 0.4000 - val_loss: 2.9799
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 9.3113e-04 - val_accuracy: 0.4000 - val_loss: 2.9993
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9729 - loss: 0.0391 - val_accuracy: 0.4000 - val_loss: 3.0156
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0284 - val_accuracy: 0.5000 - val_loss: 3.0499
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.3002e-04 - val_accuracy: 0.5000 - val_loss: 3.1008
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5000 - val_loss: 3.1481
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9729 - loss: 0.1831 - val_accuracy: 0.5000 - val_loss: 3.1407
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.7936e-04 - val_accuracy: 0.5000 - val_loss: 3.1298
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5000 - val_loss: 3.1127
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0439 - val_accuracy: 0.5000 - val_loss: 3.0524
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.4000 - val_loss: 3.0022
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.4000 - val_loss: 2.9797
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.4000 - val_loss: 2.9883
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4000 - val_loss: 3.0046
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.4000 - val_loss: 3.0107
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.0572 - val_accuracy: 0.4000 - val_loss: 3.0288
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9729 - loss: 0.0252 - val_accuracy: 0.4000 - val_loss: 3.0271
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 2.3674e-04 - val_accuracy: 0.4000 - val_loss: 3.0277
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4000 - val_loss: 3.0310
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 0.1628 - val_accuracy: 0.4000 - val_loss: 3.0667
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.4000 - val_loss: 3.0950
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.9839e-04 - val_accuracy: 0.4000 - val_loss: 3.1067
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.4000 - val_loss: 3.1075
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0178 - val_accuracy: 0.4000 - val_loss: 3.0809
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.4000 - val_loss: 3.0370
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 0.5000 - val_loss: 3.0254
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.5000 - val_loss: 3.0366
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.2921e-04 - val_accuracy: 0.5000 - val_loss: 3.0453
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 2.2496e-04 - val_accuracy: 0.5000 - val_loss: 3.0622
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.4000 - val_loss: 3.0934
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.4000 - val_loss: 3.1130
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.4000 - val_loss: 3.1813
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 0.1182 - val_accuracy: 0.4000 - val_loss: 3.2833
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.4000 - val_loss: 3.3688
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.3372e-04 - val_accuracy: 0.4000 - val_loss: 3.4444
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.2152e-04 - val_accuracy: 0.4000 - val_loss: 3.5047
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0481 - val_accuracy: 0.4000 - val_loss: 3.5154
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.4000 - val_loss: 3.4971
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.4000 - val_loss: 3.4839
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.0356 - val_accuracy: 0.4000 - val_loss: 3.4760
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.0308 - val_accuracy: 0.4000 - val_loss: 3.4797
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.8885e-04 - val_accuracy: 0.4000 - val_loss: 3.4661
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4000 - val_loss: 3.4531
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.4000 - val_loss: 3.4404
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.9462e-04 - val_accuracy: 0.4000 - val_loss: 3.4321
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.4000 - val_loss: 3.4246
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0470 - val_accuracy: 0.4000 - val_loss: 3.4281
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.4000 - val_loss: 3.4371
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.9653e-04 - val_accuracy: 0.4000 - val_loss: 3.4435
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.4000 - val_loss: 3.4407
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.4000 - val_loss: 3.4378
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.4000 - val_loss: 3.4353
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.6293e-04 - val_accuracy: 0.4000 - val_loss: 3.4342
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9729 - loss: 0.0227 - val_accuracy: 0.4000 - val_loss: 3.4268
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.0317e-04 - val_accuracy: 0.4000 - val_loss: 3.4183
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9563 - loss: 0.1501 - val_accuracy: 0.4000 - val_loss: 3.7172
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 2.2235e-04 - val_accuracy: 0.4000 - val_loss: 4.0827
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.4000 - val_loss: 4.2451
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9729 - loss: 0.0288 - val_accuracy: 0.4000 - val_loss: 4.3432
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9458 - loss: 0.1537 - val_accuracy: 0.4000 - val_loss: 4.3515
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.4811e-04 - val_accuracy: 0.4000 - val_loss: 4.3823
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4000 - val_loss: 4.3956
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.4000 - val_loss: 4.3697
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.4000 - val_loss: 4.3754

# %%
for images, labels in train_data.take(1):
    for i in range(1):
        ax = plt.subplot(3, 3, i + 1)
        #print(images[i].numpy().max())
        plt.imshow(images[i].numpy(),cmap='gray' )
        plt.title(class_names[labels[i]])
        plt.axis("off")
        print(np.round(model.predict(images[:1])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0. 1.]]
# 2024-07-22 20:33:06.735316: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
img_path = 'shapes/0/1721691260.jpg'
newimg = tf.keras.utils.load_img(
    path=img_path,
    color_mode='grayscale',
    target_size=(30,30),
    interpolation='nearest',
    keep_aspect_ratio=False
)
newimg
# Out:
# <PIL.Image.Image image mode=L size=30x30>

# %%
input_arr = tf.keras.utils.img_to_array(newimg)
input_arr = np.array([input_arr])  # Convert single image to a batch.
print(np.round(model.predict(input_arr)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# [[1. 0.]]

# %%
plt.figure(figsize=(10,8))
plt.plot(history.epoch, history.history['loss'], label = 'Training Loss')
plt.plot(history.epoch, history.history['val_loss'], label = 'Validation Loss')
plt.legend(loc='best')

# %%
plt.figure(figsize=(10,8))
plt.plot(history.epoch, history.history['accuracy'], label = 'Training Accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], label = 'Validation Accuracy')
plt.legend(loc='best')

# %%
model.save('app/shapes_v1.keras')

# %%
from tensorflow import keras
model = keras.models.load_model('app/shapes_v1.keras')

# %%
input_arr = tf.keras.utils.img_to_array(newimg)
input_arr = np.array([input_arr])  # Convert single image to a batch.
print(np.round(model.predict(input_arr)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[1. 0.]]
